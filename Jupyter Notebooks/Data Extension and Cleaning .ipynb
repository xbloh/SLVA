# %% [markdown]
# <h1> Data Expansion and Cleaning </h1>

# %% [markdown]
# <h3>Contents:</h3>
#
# 1) [Exploratory Data Analysis](#EDA) <br>
# 2) [Creating HSG only dataframe](#HSG_Only) <br>
# 3) [Categorize data source (Survey or directly given by the school)](#8020) <br>
# 4) [Calculate relative rank and score, assigning a state change](#Rel_state)<br>
# 5) [Using Geocoding API to retrieve school-specific geo coodinates](#Geocoding) <br>
# 6) [Fixing 2021 Data (eventually not used for data visualization)](#2021)

# %% [markdown]
# <h2> Exploratory Data Analysis </h2>
# <a id="EDA"></a>
# <br>
# <b> Overview </b>
# <br>
# The data given was relatively clean with no missing information except those of the 2 and 3 year average. These can be understood for the irregularities in the years which a school participates in ranking. School names were spelled regularly throughout the data source. An assumption we have taken is that the school programs compared for the Financial Times OE Ranking are similar enough to make a fair comparison.
# <br>
# <h3> Loading data from source </h3>

# %%
import pandas as pd

path = ('FT OE rankings 2007-2020.xlsx')
xl = pd.ExcelFile(path)
print(xl.sheet_names)
# Out:
# ['OE 2007-20']

# %%
df = pd.read_excel ("FT OE rankings 2007-2020.xlsx")
df
# Out:
#       Ranking       Year  Rank  3-year average            School name  \
# 0          OE 2020-01-01     1             1.0                    IMD
# 1          OE 2020-01-01     1             1.0                    IMD
# 2          OE 2020-01-01     1             1.0                    IMD
# 3          OE 2020-01-01     1             1.0                    IMD
# 4          OE 2020-01-01     1             1.0                    IMD
# ...       ...        ...   ...             ...                    ...
# 15115      OE 2007-01-01    50             NaN  Lagos Business School
# 15116      OE 2007-01-01    50             NaN  Lagos Business School
# 15117      OE 2007-01-01    50             NaN  Lagos Business School
# 15118      OE 2007-01-01    50             NaN  Lagos Business School
# 15119      OE 2007-01-01    50             NaN  Lagos Business School
#
#       EBS 2019 TOP 20      Country Europe DACH              Ranking criteria  \
# 0                 Yes  Switzerland    Yes  Yes                 Aims achieved
# 1                 Yes  Switzerland    Yes  Yes                 Course design
# 2                 Yes  Switzerland    Yes  Yes                    Facilities
# 3                 Yes  Switzerland    Yes  Yes                       Faculty
# 4                 Yes  Switzerland    Yes  Yes             Faculty diversity
# ...               ...          ...    ...  ...                           ...
# 15115              No      Nigeria     No   No         New skills & learning
# 15116              No      Nigeria     No   No               Partner schools
# 15117              No      Nigeria     No   No                   Preparation
# 15118              No      Nigeria     No   No       Quality of participants
# 15119              No      Nigeria     No   No  Teaching methods & materials
#
#        Ranking weight  Value
# 0                 8.4      4
# 1                 8.6      4
# 2                 7.6      3
# 3                 8.7      2
# 4                 5.0      5
# ...               ...    ...
# 15115             8.8     50
# 15116             3.0     30
# 15117             7.8     50
# 15118             7.9     50
# 15119             8.3     50
#
# [15120 rows x 12 columns]

# %%
#Adding column parameter HSG --> boolean integer
df['HSG']=(df['School name']=='University of St Gallen').astype(int)

# %%
#display table
df
# Out:
#       Ranking       Year  Rank  3-year average            School name  \
# 0          OE 2020-01-01     1             1.0                    IMD
# 1          OE 2020-01-01     1             1.0                    IMD
# 2          OE 2020-01-01     1             1.0                    IMD
# 3          OE 2020-01-01     1             1.0                    IMD
# 4          OE 2020-01-01     1             1.0                    IMD
# ...       ...        ...   ...             ...                    ...
# 15115      OE 2007-01-01    50             NaN  Lagos Business School
# 15116      OE 2007-01-01    50             NaN  Lagos Business School
# 15117      OE 2007-01-01    50             NaN  Lagos Business School
# 15118      OE 2007-01-01    50             NaN  Lagos Business School
# 15119      OE 2007-01-01    50             NaN  Lagos Business School
#
#       EBS 2019 TOP 20      Country Europe DACH              Ranking criteria  \
# 0                 Yes  Switzerland    Yes  Yes                 Aims achieved
# 1                 Yes  Switzerland    Yes  Yes                 Course design
# 2                 Yes  Switzerland    Yes  Yes                    Facilities
# 3                 Yes  Switzerland    Yes  Yes                       Faculty
# 4                 Yes  Switzerland    Yes  Yes             Faculty diversity
# ...               ...          ...    ...  ...                           ...
# 15115              No      Nigeria     No   No         New skills & learning
# 15116              No      Nigeria     No   No               Partner schools
# 15117              No      Nigeria     No   No                   Preparation
# 15118              No      Nigeria     No   No       Quality of participants
# 15119              No      Nigeria     No   No  Teaching methods & materials
#
#        Ranking weight  Value  HSG
# 0                 8.4      4    0
# 1                 8.6      4    0
# 2                 7.6      3    0
# 3                 8.7      2    0
# 4                 5.0      5    0
# ...               ...    ...  ...
# 15115             8.8     50    0
# 15116             3.0     30    0
# 15117             7.8     50    0
# 15118             7.9     50    0
# 15119             8.3     50    0
#
# [15120 rows x 13 columns]

# %%
print(df['Ranking criteria'].unique())

ranking_criterias = df['Ranking criteria'].unique()
# Out:
# ['Aims achieved' 'Course design' 'Facilities' 'Faculty'
#  'Faculty diversity' 'Female participants' 'Follow-up'
#  'Food & accommodation' 'Growth' 'International location'
#  'International participants' 'New skills & learning' 'Partner schools'
#  'Preparation' 'Quality of participants' 'Teaching methods & materials']

# %%
#convert Year to numerical year only
df['Year'] = df['Year'].dt.year

# %%
# realise different schools rank different criterias differently
by_year_hsg = df[df["School name"]=='University of St Gallen'].groupby(df['Year'])

# %%
(by_year_hsg)

# %% [markdown]
# <a id="HSG_Only"></a>
# <h3>Create column 'HSG' of values 0 and 1</h3>

# %%
hsg = df[df["School name"]=='University of St Gallen']
hsg
# Out:
#       Ranking  Year  Rank  3-year average              School name  \
# 400        OE  2020    26            26.0  University of St Gallen
# 401        OE  2020    26            26.0  University of St Gallen
# 402        OE  2020    26            26.0  University of St Gallen
# 403        OE  2020    26            26.0  University of St Gallen
# 404        OE  2020    26            26.0  University of St Gallen
# ...       ...   ...   ...             ...                      ...
# 14699      OE  2007    23             NaN  University of St Gallen
# 14700      OE  2007    23             NaN  University of St Gallen
# 14701      OE  2007    23             NaN  University of St Gallen
# 14702      OE  2007    23             NaN  University of St Gallen
# 14703      OE  2007    23             NaN  University of St Gallen
#
#       EBS 2019 TOP 20      Country Europe DACH              Ranking criteria  \
# 400               Yes  Switzerland    Yes  Yes                 Aims achieved
# 401               Yes  Switzerland    Yes  Yes                 Course design
# 402               Yes  Switzerland    Yes  Yes                    Facilities
# 403               Yes  Switzerland    Yes  Yes                       Faculty
# 404               Yes  Switzerland    Yes  Yes             Faculty diversity
# ...               ...          ...    ...  ...                           ...
# 14699             Yes  Switzerland    Yes  Yes         New skills & learning
# 14700             Yes  Switzerland    Yes  Yes               Partner schools
# 14701             Yes  Switzerland    Yes  Yes                   Preparation
# 14702             Yes  Switzerland    Yes  Yes       Quality of participants
# 14703             Yes  Switzerland    Yes  Yes  Teaching methods & materials
#
#        Ranking weight  Value  HSG
# 400               8.4     20    1
# 401               8.6     29    1
# 402               7.6     18    1
# 403               8.7     31    1
# 404               5.0     30    1
# ...               ...    ...  ...
# 14699             8.8     25    1
# 14700             3.0     10    1
# 14701             7.8      9    1
# 14702             7.9     24    1
# 14703             8.3     26    1
#
# [224 rows x 13 columns]

# %%
import numpy as np
hsg.groupby(['Year'], as_index=False)['Ranking weight']

# %% [markdown]
# <a id="8020"></a>
# <h3> Create new column to categorize data given by school and participants (values in 0 or 1)</h3>

# %%
#label boolean 1/0 for in 20p -> provided by the school
#80% provided by the participants 

#list of criterias provided by school
criteria_20p = ["Female participants","International participants", 
                "International location", "Growth", "Partner schools", "Faculty diversity"]

# %%
def categorize_source(x):
    if x in criteria_20p:
        return 1
    else:
        return 0

# %%
# df[df["Ranking criteria"] in criteria_20p]
df['20p'] =  df['Ranking criteria'].apply(categorize_source)

# %%
df
# Out:
#       Ranking  Year  Rank  3-year average            School name  \
# 0          OE  2020     1             1.0                    IMD
# 1          OE  2020     1             1.0                    IMD
# 2          OE  2020     1             1.0                    IMD
# 3          OE  2020     1             1.0                    IMD
# 4          OE  2020     1             1.0                    IMD
# ...       ...   ...   ...             ...                    ...
# 15115      OE  2007    50             NaN  Lagos Business School
# 15116      OE  2007    50             NaN  Lagos Business School
# 15117      OE  2007    50             NaN  Lagos Business School
# 15118      OE  2007    50             NaN  Lagos Business School
# 15119      OE  2007    50             NaN  Lagos Business School
#
#       EBS 2019 TOP 20      Country Europe DACH              Ranking criteria  \
# 0                 Yes  Switzerland    Yes  Yes                 Aims achieved
# 1                 Yes  Switzerland    Yes  Yes                 Course design
# 2                 Yes  Switzerland    Yes  Yes                    Facilities
# 3                 Yes  Switzerland    Yes  Yes                       Faculty
# 4                 Yes  Switzerland    Yes  Yes             Faculty diversity
# ...               ...          ...    ...  ...                           ...
# 15115              No      Nigeria     No   No         New skills & learning
# 15116              No      Nigeria     No   No               Partner schools
# 15117              No      Nigeria     No   No                   Preparation
# 15118              No      Nigeria     No   No       Quality of participants
# 15119              No      Nigeria     No   No  Teaching methods & materials
#
#        Ranking weight  Value  HSG  20p
# 0                 8.4      4    0    0
# 1                 8.6      4    0    0
# 2                 7.6      3    0    0
# 3                 8.7      2    0    0
# 4                 5.0      5    0    1
# ...               ...    ...  ...  ...
# 15115             8.8     50    0    0
# 15116             3.0     30    0    1
# 15117             7.8     50    0    0
# 15118             7.9     50    0    0
# 15119             8.3     50    0    0
#
# [15120 rows x 14 columns]

# %%
df.to_excel("OE_v1.xlsx")

# %% [markdown]
# <a id="Rel_state"></a>
# <h3>Create new column 'Relative value' to give the relative score per ranking criteria for each year</h3>

# %% [markdown]
# The relative rank or score was calculated per ranking criteria, per year for a year on year comparison for each ranking criteria, and each school. The algorithm is as follows.
#
# By grouping the data points by the year and calculating the number of unique school names in each year, we found that there are different number of schools in each year.
#
# The relative rank is calculated by dividing the rank with the total number of unique school names in that year to give a value between 0 and 1.

# %%
num_schools_arr = df.groupby(["Year"]).nunique()["School name"]

# %%
num_schools_arr
# Out:
# Year
# 2007    50
# 2008    50
# 2009    55
# 2010    60
# 2011    65
# 2012    65
# 2013    70
# 2014    70
# 2015    75
# 2016    75
# 2017    75
# 2018    80
# 2019    80
# 2020    75
# Name: School name, dtype: int64

# %% [markdown]
# Notice that each year has a different number of competing schools, we need to be careful of each school in the dataset for its school name (spelling errors) and that different years have a different set of participating schools.

# %%
num_schools_arr[df.loc[9]["Year"]] 

#cross checking with visual evaluation of dataset
# Out:
# 75

# %%
rel = []
for i in range(0,len(df)):
    res = df["Value"][i]/num_schools_arr[df.loc[i]["Year"]]
    rel.append(res)

rel
# Out:
# [0.05333333333333334,
#  0.05333333333333334,
#  0.04,
#  0.02666666666666667,
#  0.06666666666666667,
#  0.36,
#  0.10666666666666667,
#  0.02666666666666667,
#  0.38666666666666666,
#  0.49333333333333335,
#  0.08,
#  0.04,
#  0.5733333333333334,
#  0.09333333333333334,
#  0.05333333333333334,
#  0.013333333333333334,
#  0.04,
#  0.04,
#  0.12,
#  0.04,
#  0.09333333333333334,
#  0.48,
#  0.04,
#  0.22666666666666666,
#  0.4666666666666667,
#  0.48,
#  0.12,
#  0.06666666666666667,
#  0.21333333333333335,
#  0.06666666666666667,
#  0.02666666666666667,
#  0.05333333333333334,
#  0.08,
#  0.10666666666666667,
#  0.06666666666666667,
#  0.08,
#  0.05333333333333334,
#  0.44,
#  0.13333333333333333,
#  0.10666666666666667,
#  0.41333333333333333,
#  0.28,
#  0.05333333333333334,
#  0.22666666666666666,
#  0.3466666666666667,
#  0.13333333333333333,
#  0.04,
#  0.06666666666666667,
#  0.02666666666666667,
#  0.013333333333333334,
#  0.013333333333333334,
#  0.013333333333333334,
#  0.56,
#  0.76,
#  0.26666666666666666,
#  0.14666666666666667,
#  0.5066666666666667,
#  0.26666666666666666,
#  0.4266666666666667,
#  0.02666666666666667,
#  0.4,
#  0.05333333333333334,
#  0.10666666666666667,
#  0.02666666666666667,
#  0.013333333333333334,
#  0.17333333333333334,
#  0.08,
#  0.06666666666666667,
#  0.7066666666666667,
#  0.44,
#  0.2,
#  0.013333333333333334,
#  0.56,
#  0.7466666666666667,
#  0.13333333333333333,
#  0.05333333333333334,
#  0.48,
#  0.04,
#  0.013333333333333334,
#  0.08,
#  0.13333333333333333,
#  0.09333333333333334,
#  0.05333333333333334,
#  0.09333333333333334,
#  0.4266666666666667,
#  0.4266666666666667,
#  0.18666666666666668,
#  0.04,
#  0.24,
#  0.32,
#  0.24,
#  0.09333333333333334,
#  0.28,
#  0.02666666666666667,
#  0.09333333333333334,
#  0.16,
#  0.14666666666666667,
#  0.12,
#  0.09333333333333334,
#  0.12,
#  0.44,
#  0.48,
#  0.12,
#  0.09333333333333334,
#  0.26666666666666666,
#  0.38666666666666666,
#  0.14666666666666667,
#  0.12,
#  0.2,
#  0.08,
#  0.06666666666666667,
#  0.13333333333333333,
#  0.17333333333333334,
#  0.2,
#  0.10666666666666667,
#  0.24,
#  0.08,
#  0.5866666666666667,
#  0.013333333333333334,
#  0.26666666666666666,
#  0.16,
#  0.013333333333333334,
#  0.10666666666666667,
#  0.08,
#  0.09333333333333334,
#  0.25333333333333335,
#  0.14666666666666667,
#  0.14666666666666667,
#  0.06666666666666667,
#  0.13333333333333333,
#  0.02666666666666667,
#  0.10666666666666667,
#  0.5066666666666667,
#  0.38666666666666666,
#  0.16,
#  0.05333333333333334,
#  0.76,
#  0.56,
#  0.48,
#  0.3333333333333333,
#  0.56,
#  0.8666666666666667,
#  0.84,
#  0.7733333333333333,
#  0.84,
#  0.48,
#  0.72,
#  0.6266666666666667,
#  0.4,
#  0.8933333333333333,
#  0.4533333333333333,
#  0.04,
#  0.5866666666666667,
#  0.6133333333333333,
#  0.76,
#  0.13333333333333333,
#  0.7466666666666667,
#  0.8933333333333333,
#  0.9733333333333334,
#  0.3466666666666667,
#  0.6266666666666667,
#  0.9733333333333334,
#  0.8533333333333334,
#  0.6666666666666666,
#  0.7066666666666667,
#  0.88,
#  0.76,
#  0.72,
#  0.6933333333333334,
#  0.7466666666666667,
#  0.6266666666666667,
#  0.6533333333333333,
#  0.4266666666666667,
#  0.9333333333333333,
#  0.6133333333333333,
#  0.8533333333333334,
#  0.8,
#  0.4,
#  0.49333333333333335,
#  0.96,
#  0.26666666666666666,
#  0.7866666666666666,
#  0.36,
#  0.68,
#  0.96,
#  0.7333333333333333,
#  0.72,
#  0.6533333333333333,
#  0.68,
#  0.88,
#  0.6933333333333334,
#  0.56,
#  0.7066666666666667,
#  0.9866666666666667,
#  0.6533333333333333,
#  0.4666666666666667,
#  0.7866666666666666,
#  0.8533333333333334,
#  0.9066666666666666,
#  0.9733333333333334,
#  0.6133333333333333,
#  0.9866666666666667,
#  0.8533333333333334,
#  0.6533333333333333,
#  0.5866666666666667,
#  0.30666666666666664,
#  0.5466666666666666,
#  0.8266666666666667,
#  0.88,
#  0.7333333333333333,
#  0.92,
#  0.2,
#  0.5466666666666666,
#  0.7466666666666667,
#  0.9333333333333333,
#  0.5733333333333334,
#  0.22666666666666666,
#  0.30666666666666664,
#  0.6133333333333333,
#  0.16,
#  1.0,
#  0.6666666666666666,
#  0.68,
#  0.7866666666666666,
#  0.8133333333333334,
#  0.7066666666666667,
#  0.8933333333333333,
#  0.8266666666666667,
#  0.72,
#  0.6666666666666666,
#  0.6533333333333333,
#  0.09333333333333334,
#  0.6,
#  0.5866666666666667,
#  0.92,
#  0.14666666666666667,
#  0.8266666666666667,
#  0.84,
#  0.8266666666666667,
#  0.96,
#  0.9733333333333334,
#  0.4266666666666667,
#  0.8133333333333334,
#  0.5733333333333334,
#  0.52,
#  0.5866666666666667,
#  0.8533333333333334,
#  0.013333333333333334,
#  0.06666666666666667,
#  0.76,
#  0.9733333333333334,
#  0.44,
#  0.5466666666666666,
#  0.7733333333333333,
#  1.0,
#  0.8133333333333334,
#  0.6133333333333333,
#  0.9333333333333333,
#  0.6933333333333334,
#  0.4666666666666667,
#  0.6,
#  0.76,
#  0.7866666666666666,
#  ...]

# %%
df["Relative_value"] = rel

# %%
df
# Out:
#       Ranking  Year  Rank  3-year average            School name  \
# 0          OE  2020     1             1.0                    IMD
# 1          OE  2020     1             1.0                    IMD
# 2          OE  2020     1             1.0                    IMD
# 3          OE  2020     1             1.0                    IMD
# 4          OE  2020     1             1.0                    IMD
# ...       ...   ...   ...             ...                    ...
# 15115      OE  2007    50             NaN  Lagos Business School
# 15116      OE  2007    50             NaN  Lagos Business School
# 15117      OE  2007    50             NaN  Lagos Business School
# 15118      OE  2007    50             NaN  Lagos Business School
# 15119      OE  2007    50             NaN  Lagos Business School
#
#       EBS 2019 TOP 20      Country Europe DACH              Ranking criteria  \
# 0                 Yes  Switzerland    Yes  Yes                 Aims achieved
# 1                 Yes  Switzerland    Yes  Yes                 Course design
# 2                 Yes  Switzerland    Yes  Yes                    Facilities
# 3                 Yes  Switzerland    Yes  Yes                       Faculty
# 4                 Yes  Switzerland    Yes  Yes             Faculty diversity
# ...               ...          ...    ...  ...                           ...
# 15115              No      Nigeria     No   No         New skills & learning
# 15116              No      Nigeria     No   No               Partner schools
# 15117              No      Nigeria     No   No                   Preparation
# 15118              No      Nigeria     No   No       Quality of participants
# 15119              No      Nigeria     No   No  Teaching methods & materials
#
#        Ranking weight  Value  HSG  20p  Relative_value
# 0                 8.4      4    0    0        0.053333
# 1                 8.6      4    0    0        0.053333
# 2                 7.6      3    0    0        0.040000
# 3                 8.7      2    0    0        0.026667
# 4                 5.0      5    0    1        0.066667
# ...               ...    ...  ...  ...             ...
# 15115             8.8     50    0    0        1.000000
# 15116             3.0     30    0    1        0.600000
# 15117             7.8     50    0    0        1.000000
# 15118             7.9     50    0    0        1.000000
# 15119             8.3     50    0    0        1.000000
#
# [15120 rows x 15 columns]

# %% [markdown]
# <b>Mark the status by calculating the percentage change, assigning it to column 'state' and categorizing the 'State change' value by 0, 1 and -1.</b><br>
# We also calculate the percentage change of that relative rank with its previous years and assign it a ‘state change’ to reflect a positive, neutral or negative change. These are denoted by 1, 0 and -1 respectively in our extended dataset. As some schools are not in the participating schools list each year, the inconsistency creates some empty data points for this attribute. A state of 0 or neutral has been assigned to these to indicate that they did not change from its previous year. This is an assumption made that the value did not change for the year that a school did not participate in the Financial Times OE Ranking.

# %%
df["state"] = df.sort_values('Year').groupby(
    ['Ranking criteria', 'School name']).Relative_value.pct_change()
df['state']= df['state'].fillna(value=0)
df
# Out:
#       Ranking  Year  Rank  3-year average            School name  \
# 0          OE  2020     1             1.0                    IMD
# 1          OE  2020     1             1.0                    IMD
# 2          OE  2020     1             1.0                    IMD
# 3          OE  2020     1             1.0                    IMD
# 4          OE  2020     1             1.0                    IMD
# ...       ...   ...   ...             ...                    ...
# 15115      OE  2007    50             NaN  Lagos Business School
# 15116      OE  2007    50             NaN  Lagos Business School
# 15117      OE  2007    50             NaN  Lagos Business School
# 15118      OE  2007    50             NaN  Lagos Business School
# 15119      OE  2007    50             NaN  Lagos Business School
#
#       EBS 2019 TOP 20      Country Europe DACH              Ranking criteria  \
# 0                 Yes  Switzerland    Yes  Yes                 Aims achieved
# 1                 Yes  Switzerland    Yes  Yes                 Course design
# 2                 Yes  Switzerland    Yes  Yes                    Facilities
# 3                 Yes  Switzerland    Yes  Yes                       Faculty
# 4                 Yes  Switzerland    Yes  Yes             Faculty diversity
# ...               ...          ...    ...  ...                           ...
# 15115              No      Nigeria     No   No         New skills & learning
# 15116              No      Nigeria     No   No               Partner schools
# 15117              No      Nigeria     No   No                   Preparation
# 15118              No      Nigeria     No   No       Quality of participants
# 15119              No      Nigeria     No   No  Teaching methods & materials
#
#        Ranking weight  Value  HSG  20p  Relative_value     state
# 0                 8.4      4    0    0        0.053333 -0.466667
# 1                 8.6      4    0    0        0.053333 -0.466667
# 2                 7.6      3    0    0        0.040000 -0.600000
# 3                 8.7      2    0    0        0.026667  0.066667
# 4                 5.0      5    0    1        0.066667  1.666667
# ...               ...    ...  ...  ...             ...       ...
# 15115             8.8     50    0    0        1.000000  0.000000
# 15116             3.0     30    0    1        0.600000  0.000000
# 15117             7.8     50    0    0        1.000000  0.000000
# 15118             7.9     50    0    0        1.000000  0.000000
# 15119             8.3     50    0    0        1.000000  0.000000
#
# [15120 rows x 16 columns]

# %%
df[df["School name"]=='University of St Gallen']
# Out:
#       Ranking  Year  Rank  3-year average              School name  \
# 400        OE  2020    26            26.0  University of St Gallen
# 401        OE  2020    26            26.0  University of St Gallen
# 402        OE  2020    26            26.0  University of St Gallen
# 403        OE  2020    26            26.0  University of St Gallen
# 404        OE  2020    26            26.0  University of St Gallen
# ...       ...   ...   ...             ...                      ...
# 14699      OE  2007    23             NaN  University of St Gallen
# 14700      OE  2007    23             NaN  University of St Gallen
# 14701      OE  2007    23             NaN  University of St Gallen
# 14702      OE  2007    23             NaN  University of St Gallen
# 14703      OE  2007    23             NaN  University of St Gallen
#
#       EBS 2019 TOP 20      Country Europe DACH              Ranking criteria  \
# 400               Yes  Switzerland    Yes  Yes                 Aims achieved
# 401               Yes  Switzerland    Yes  Yes                 Course design
# 402               Yes  Switzerland    Yes  Yes                    Facilities
# 403               Yes  Switzerland    Yes  Yes                       Faculty
# 404               Yes  Switzerland    Yes  Yes             Faculty diversity
# ...               ...          ...    ...  ...                           ...
# 14699             Yes  Switzerland    Yes  Yes         New skills & learning
# 14700             Yes  Switzerland    Yes  Yes               Partner schools
# 14701             Yes  Switzerland    Yes  Yes                   Preparation
# 14702             Yes  Switzerland    Yes  Yes       Quality of participants
# 14703             Yes  Switzerland    Yes  Yes  Teaching methods & materials
#
#        Ranking weight  Value  HSG  20p  Relative_value     state
# 400               8.4     20    1    0        0.266667  0.254902
# 401               8.6     29    1    0        0.386667  0.344928
# 402               7.6     18    1    0        0.240000 -0.085714
# 403               8.7     31    1    0        0.413333  0.033333
# 404               5.0     30    1    1        0.400000  0.000000
# ...               ...    ...  ...  ...             ...       ...
# 14699             8.8     25    1    0        0.500000  0.000000
# 14700             3.0     10    1    1        0.200000  0.000000
# 14701             7.8      9    1    0        0.180000  0.000000
# 14702             7.9     24    1    0        0.480000  0.000000
# 14703             8.3     26    1    0        0.520000  0.000000
#
# [224 rows x 16 columns]

# %%
def categorize_state(x):
    if x>0:
        return 1
    elif x==0:
        return 0
    else:
        return -1

# %%
df["state_change"]=df['state'].apply(categorize_state)
df
# Out:
#       Ranking  Year  Rank  3-year average            School name  \
# 0          OE  2020     1             1.0                    IMD
# 1          OE  2020     1             1.0                    IMD
# 2          OE  2020     1             1.0                    IMD
# 3          OE  2020     1             1.0                    IMD
# 4          OE  2020     1             1.0                    IMD
# ...       ...   ...   ...             ...                    ...
# 15115      OE  2007    50             NaN  Lagos Business School
# 15116      OE  2007    50             NaN  Lagos Business School
# 15117      OE  2007    50             NaN  Lagos Business School
# 15118      OE  2007    50             NaN  Lagos Business School
# 15119      OE  2007    50             NaN  Lagos Business School
#
#       EBS 2019 TOP 20      Country Europe DACH              Ranking criteria  \
# 0                 Yes  Switzerland    Yes  Yes                 Aims achieved
# 1                 Yes  Switzerland    Yes  Yes                 Course design
# 2                 Yes  Switzerland    Yes  Yes                    Facilities
# 3                 Yes  Switzerland    Yes  Yes                       Faculty
# 4                 Yes  Switzerland    Yes  Yes             Faculty diversity
# ...               ...          ...    ...  ...                           ...
# 15115              No      Nigeria     No   No         New skills & learning
# 15116              No      Nigeria     No   No               Partner schools
# 15117              No      Nigeria     No   No                   Preparation
# 15118              No      Nigeria     No   No       Quality of participants
# 15119              No      Nigeria     No   No  Teaching methods & materials
#
#        Ranking weight  Value  HSG  20p  Relative_value     state  state_change
# 0                 8.4      4    0    0        0.053333 -0.466667            -1
# 1                 8.6      4    0    0        0.053333 -0.466667            -1
# 2                 7.6      3    0    0        0.040000 -0.600000            -1
# 3                 8.7      2    0    0        0.026667  0.066667             1
# 4                 5.0      5    0    1        0.066667  1.666667             1
# ...               ...    ...  ...  ...             ...       ...           ...
# 15115             8.8     50    0    0        1.000000  0.000000             0
# 15116             3.0     30    0    1        0.600000  0.000000             0
# 15117             7.8     50    0    0        1.000000  0.000000             0
# 15118             7.9     50    0    0        1.000000  0.000000             0
# 15119             8.3     50    0    0        1.000000  0.000000             0
#
# [15120 rows x 17 columns]

# %%
# df.to_excel("OE_v2.xlsx")

# %% [markdown]
# ### EDA Continued

# %%
hsg.sort_values(['Year'],ascending=True).groupby(['Year','Ranking criteria',"School name"]).head()
# Out:
#       Ranking  Year  Rank  3-year average              School name  \
# 14703      OE  2007    23             NaN  University of St Gallen
# 14688      OE  2007    23             NaN  University of St Gallen
# 14689      OE  2007    23             NaN  University of St Gallen
# 14690      OE  2007    23             NaN  University of St Gallen
# 14691      OE  2007    23             NaN  University of St Gallen
# ...       ...   ...   ...             ...                      ...
# 413        OE  2020    26            26.0  University of St Gallen
# 414        OE  2020    26            26.0  University of St Gallen
# 415        OE  2020    26            26.0  University of St Gallen
# 408        OE  2020    26            26.0  University of St Gallen
# 400        OE  2020    26            26.0  University of St Gallen
#
#       EBS 2019 TOP 20      Country Europe DACH              Ranking criteria  \
# 14703             Yes  Switzerland    Yes  Yes  Teaching methods & materials
# 14688             Yes  Switzerland    Yes  Yes                 Aims achieved
# 14689             Yes  Switzerland    Yes  Yes                 Course design
# 14690             Yes  Switzerland    Yes  Yes                    Facilities
# 14691             Yes  Switzerland    Yes  Yes                       Faculty
# ...               ...          ...    ...  ...                           ...
# 413               Yes  Switzerland    Yes  Yes                   Preparation
# 414               Yes  Switzerland    Yes  Yes       Quality of participants
# 415               Yes  Switzerland    Yes  Yes  Teaching methods & materials
# 408               Yes  Switzerland    Yes  Yes                        Growth
# 400               Yes  Switzerland    Yes  Yes                 Aims achieved
#
#        Ranking weight  Value  HSG
# 14703             8.3     26    1
# 14688             8.6     19    1
# 14689             8.7     27    1
# 14690             7.4     27    1
# 14691             9.0     28    1
# ...               ...    ...  ...
# 413               7.7     11    1
# 414               7.9     56    1
# 415               8.3     24    1
# 408               5.0     71    1
# 400               8.4     20    1
#
# [224 rows x 13 columns]

# %%
# Assumption 1: the ranking weight aggregates with a 3 year average or 2 year average

# %%
#data viz 1: "ranking weight and 20p": target the more influential data. e.g. participant response --> invest more to improve perception and experience

# %%
#finding out why HSG is ranked lower/higher

# assumption 2: is the program compared similar enough to make a comparison? --> yes, already similar enough

# %% [markdown]
# <a id="Geocoding"></a>
# <h3>Including Geocoding for more specific coordinates</h3>
# <br>
# This was done with three attempts with three different APIs. The one we eventually used was the Google Geocoding API. The two others were GeoCodio and Open Street Maps. The reason that GeoCodio and Open Street Maps were not suitable were that the school names were not able to successfully invoke a request for the geo-coordinates. In other words, they are not robust enough to accept different forms of a school name and correct or redirect it like the Google API can. We attempted changing the school names and cleaning it with regex when using the other 2 APIs but realized it was not feasible to do so for all the schools that faced such a problem. For Open Street Maps, more than half of the school names required modification, manually. With Google Maps, we only needed to modify about 5 school names. Though it still required some manual modification, it was not as time consuming.

# %% [markdown]
# <h4>[Attempt, Method 1] Using GeoCodio</h4>

# %%
geocode_api_key =

# %%
# !pip install pygeocodio
from geocodio import GeocodioClient
client = GeocodioClient(geocode_api_key, timeout = 15)
geocoded_location = client.geocode("University of Oxford: Saïd")
geocoded_location.coords

# locations = client.batch_geocode(df['School name'].unique())
# Out:
# (39.521163, -84.376804)

# %%
df['School name'].unique()
# Out:
# array(['IMD', 'University of Oxford: Saïd', 'Insead',
#        'University of Michigan: Ross',
#        'Stanford Graduate School of Business',
#        'University of Chicago: Booth',
#        'University of Pennsylvania: Wharton', 'HEC Paris', 'ESMT Berlin',
#        'Iese Business School', 'Columbia Business School',
#        'UCLA Anderson School of Management', 'Fundação Dom Cabral',
#        'Washington University: Olin', 'Esade Business School',
#        'Essec Business School', 'University of Toronto: Rotman',
#        'Stockholm School of Economics', 'University of Cambridge: Judge',
#        'Western University: Ivey', 'London Business School',
#        'Henley Business School', 'Hult Ashridge Executive Education',
#        'Kaist College of Business', 'SDA Bocconi School of Management',
#        'University of St Gallen', 'Nyenrode Business Universiteit',
#        "Queen's University: Smith",
#        'Shanghai Jiao Tong University: Antai', 'Ceibs',
#        'Vlerick Business School', 'Cranfield School of Management',
#        'Gordon Institute of Business Science at UP',
#        'NHH Norwegian School of Economics',
#        'AGSM at UNSW Business School',
#        'National University of Singapore Business School',
#        'IE Business School', 'WHU – Otto Beisheim School of Management',
#        'Incae Business School', 'Edhec Business School',
#        'ESCP Business School',
#        'Thunderbird School of Global Management at ASU',
#        'University College Dublin: Smurfit',
#        'Universidad de los Andes School of Management',
#        'York University: Schulich', 'Eada Business School Barcelona',
#        'University of British Columbia: Sauder',
#        'Nova School of Business and Economics', 'Rutgers Business School',
#        'Frankfurt School of Finance and Management',
#        'University of Arizona: Eller', 'Ipade Business School',
#        'Tias Business School',
#        'Rotterdam School of Management, Erasmus University',
#        'Indian Institute of Management Bangalore', 'IAE Business School',
#        'Copenhagen Business School',
#        'Indian Institute of Management Ahmedabad',
#        'Florida Atlantic University College of Business',
#        'Grenoble Ecole de Management', 'Aalto University',
#        'Moscow School of Management Skolkovo',
#        'Alberta School of Business', 'EMLyon Business School',
#        'BI Norwegian Business School', 'Audencia Business School',
#        'Irish Management Institute',
#        'American University in Cairo School of Business',
#        'Lagos Business School', 'McGill University: Desautels',
#        'Kedge Business School',
#        'Católica Lisbon School of Business and Economics',
#        'Solvay Brussels School of Economics and Management',
#        'Politecnico di Milano School of Management',
#        'Porto Business School', 'Center for Creative Leadership',
#        'University of Virginia: Darden', 'Boston University: Questrom',
#        'Insper', 'HEC Montreal', 'Esan',
#        'Centrum PUCP Graduate Business School',
#        'Indian School of Business', 'Harvard Business School',
#        'MIT: Sloan', 'Peking University: Guanghua',
#        'University of Alberta', 'Melbourne Business School',
#        'USB Executive Development', 'ISCTE Business School',
#        'University of Pretoria, Gibs',
#        'Fundação Instituto de Administração',
#        'Saint Paul Escola de Negócios', 'Wits Business School',
#        'Northwestern University: Kellogg', 'Sun Yat-sen Business School',
#        'Xiamen University School of Management',
#        'University of Texas at Austin: McCombs',
#        'University of California at Berkeley: Haas',
#        'Universidad Externado de Colombia', 'Euromed Management',
#        'Wisconsin School of Business',
#        'University of Queensland Business School',
#        'Duke University: Fuqua', 'Babson Executive Education',
#        'Macquarie Graduate School of Management'], dtype=object)

# %%
# !pip3 install urllib3
import urllib3

address="University of Queensland Business School"
key=""
url="https://maps.googleapis.com/maps/api/geocode/json?address=%s&key=%s" % (address.replace(' ','+'), key)

response = urllib3.urlopen(url)

jsongeocode = response.read()
# Out:
# Requirement already satisfied: urllib3 in c:\users\andrew ng\anaconda3\lib\site-packages (1.26.4)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-171-b1d3e4470730> in <module>
#       6 url="https://maps.googleapis.com/maps/api/geocode/json?address=%s&key=%s" % (address.replace(' ','+'), key)
#       7
# ----> 8 response = urllib3.urlopen(url)
#       9
#      10 jsongeocode = response.read()
#
# AttributeError: module 'urllib3' has no attribute 'urlopen'

# %% [markdown]
# <h4>[Used in Final] Using Google API</h4>
# <br>
# With the Python geopy and googlemaps libraries, we could also retrieve its address and we have hence added the address together with the longitude and latitude. In order to ensure we do not change the original school name in the dataset, a new column titled “reformat_name” was created for the reformatted school name that can successfully generate a positive return from the API. This was manually tested on Google Maps.

# %%
# !pip install geopy
# !pip install googlemaps
# Out:
# Collecting geopy
#   Downloading geopy-2.2.0-py3-none-any.whl (118 kB)
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.52-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.52 geopy-2.2.0
# Collecting googlemaps
#   Downloading googlemaps-4.6.0.tar.gz (31 kB)
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\users\andrew ng\anaconda3\lib\site-packages (from googlemaps) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\andrew ng\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\andrew ng\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\andrew ng\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\andrew ng\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.4)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py): started
#   Building wheel for googlemaps (setup.py): finished with status 'done'
#   Created wheel for googlemaps: filename=googlemaps-4.6.0-py3-none-any.whl size=38531 sha256=15cbcc30ced2ed3b7836dc51a4b68f13b48136ec4291a431d56ffca0d107143c
#   Stored in directory: c:\users\andrew ng\appdata\local\pip\cache\wheels\2d\e9\ee\336c1792ed04efbf4fe9c89662d701f5c1f1fdddf8782951d3
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.6.0

# %%
from geopy.geocoders import GoogleV3
import geopy.distance
import googlemaps

# %%
API="" #created own api key
geolocator = GoogleV3(api_key=API)

print(type(geolocator))
# Out:
# <class 'geopy.geocoders.google.GoogleV3'>

# %%
name = 'University of St Gallen' 
location = geolocator.geocode(name)

print(location.address)
print(location.latitude, location.longitude)
# Out:
# Dufourstrasse 50, 9000 St. Gallen, Switzerland
# 47.4321575 9.3755673

# %%
gmaps_key = googlemaps.Client(key=API)

df_schnames = pd.DataFrame(df['School name'].unique())

# %%
df_schnames
# Out:
#                                             0
# 0                                         IMD
# 1                  University of Oxford: Saïd
# 2                                      Insead
# 3                University of Michigan: Ross
# 4        Stanford Graduate School of Business
# ..                                        ...
# 101              Wisconsin School of Business
# 102  University of Queensland Business School
# 103                    Duke University: Fuqua
# 104                Babson Executive Education
# 105   Macquarie Graduate School of Management
#
# [106 rows x 1 columns]

# %%
df_schnames=df_schnames.rename(index=str, columns={0:'School name'})

# %%
g=gmaps_key.geocode('ESAN Graduate School of Management and Business')
lat = g[0]["geometry"]["location"]["lat"]
long = g[0]["geometry"]["location"]["lng"]
print('Latitude: '+str(lat)+', Longitude: '+str(long))
# Out:
# Latitude: 38.5347704, Longitude: -121.7473888

# %%
g[0]
# Out:
# {'address_components': [{'long_name': '50',
#    'short_name': '50',
#    'types': ['street_number']},
#   {'long_name': 'Dufourstrasse',
#    'short_name': 'Dufourstrasse',
#    'types': ['route']},
#   {'long_name': 'St. Gallen',
#    'short_name': 'St. Gallen',
#    'types': ['locality', 'political']},
#   {'long_name': 'Sankt Gallen',
#    'short_name': 'St. Gallen',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': 'Sankt Gallen',
#    'short_name': 'SG',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'Switzerland',
#    'short_name': 'CH',
#    'types': ['country', 'political']},
#   {'long_name': '9000', 'short_name': '9000', 'types': ['postal_code']}],
#  'formatted_address': 'Dufourstrasse 50, 9000 St. Gallen, Switzerland',
#  'geometry': {'location': {'lat': 47.4321575, 'lng': 9.3755673},
#   'location_type': 'ROOFTOP',
#   'viewport': {'northeast': {'lat': 47.4338484, 'lng': 9.3774762},
#    'southwest': {'lat': 47.4297395, 'lng': 9.373839799999999}}},
#  'partial_match': True,
#  'place_id': 'ChIJud_ySkYem0cR1APJCqJflqw',
#  'plus_code': {'compound_code': 'C9JG+V6 St. Gallen, Switzerland',
#   'global_code': '8FVFC9JG+V6'},
#  'types': ['establishment', 'point_of_interest', 'university']}

# %%
def geocode_addr(add):
    try:
        g = gmaps_key.geocode(add)
        addr = g[0]["formatted_address"]
        return addr
    except:
        return ""

df_schnames['address'] = df_schnames['reformat_name'].apply(geocode_addr)

# %%
#checking for empty data
df_schnames[df_schnames['address']==""]
# Out:
# Empty DataFrame
# Columns: [School name, address, reformat_name]
# Index: []

# %%
df_schnames['reformat_name']=df_schnames['School name']
df_schnames['reformat_name']= df_schnames['reformat_name'].replace(
    ['Esan',
     'Fundação Instituto de Administração',
     'Sun Yat-sen Business School'],
    ['ESAN Graduate School of Management and Business',
     'Institute of Management Foundation',
     'School of Business Sun Yat-Sen University'])
# df_schnames[df_schnames['School name']=='Esan']

# %%
def geocode_lat(add):
    g = gmaps_key.geocode(add)
    lat = g[0]["geometry"]["location"]["lat"]
    return lat
def geocode_lon(add):
    g = gmaps_key.geocode(add)
    lng = g[0]["geometry"]["location"]["lng"]
    return lng

df_schnames['glatitude'] = df_schnames['reformat_name'].apply(
    geocode_lat)
df_schnames['glongitude'] = df_schnames['reformat_name'].apply(
    geocode_lon)
df_schnames.isnull().values.any()
# Out:
# False

# %%
df_schnames
# Out:
#                                   School name  \
# 0                                         IMD
# 1                  University of Oxford: Saïd
# 2                                      Insead
# 3                University of Michigan: Ross
# 4        Stanford Graduate School of Business
# ..                                        ...
# 101              Wisconsin School of Business
# 102  University of Queensland Business School
# 103                    Duke University: Fuqua
# 104                Babson Executive Education
# 105   Macquarie Graduate School of Management
#
#                                                address  \
# 0    Chem. de Bellerive 23, 1003 Lausanne, Switzerland
# 1                      Park End St, Oxford OX1 1HP, UK
# 2         Bd de Constance, 77300 Fontainebleau, France
# 3             701 Tappan Ave, Ann Arbor, MI 48109, USA
# 4              655 Knight Way, Stanford, CA 94305, USA
# ..                                                 ...
# 101         975 University Ave, Madison, WI 53706, USA
# 102  Colin Clark, 39 Blair Dr, St Lucia QLD 4067, A...
# 103             100 Fuqua Drive, Durham, NC 27708, USA
# 104          231 Forest St, Babson Park, MA 02457, USA
# 105  99 Talavera Rd, Macquarie Park NSW 2113, Austr...
#
#                                 reformat_name  glatitude  glongitude
# 0                                         IMD  46.510410    6.621950
# 1                  University of Oxford: Saïd  51.753252   -1.268270
# 2                                      Insead  48.405113    2.685654
# 3                University of Michigan: Ross  42.272969  -83.737863
# 4        Stanford Graduate School of Business  37.428052 -122.161173
# ..                                        ...        ...         ...
# 101              Wisconsin School of Business  43.072709  -89.401636
# 102  University of Queensland Business School -27.494711  153.014247
# 103                    Duke University: Fuqua  35.998547  -78.945901
# 104                Babson Executive Education  42.296442  -71.265708
# 105   Macquarie Graduate School of Management -33.771314  151.116176
#
# [106 rows x 5 columns]

# %%
df_oe_v2 = pd.read_excel('OE_v2.xlsx', index_col =0)
df_oe_v2
# Out:
#       Ranking  Year  Rank  3-year average            School name  \
# 0          OE  2020     1             1.0                    IMD
# 1          OE  2020     1             1.0                    IMD
# 2          OE  2020     1             1.0                    IMD
# 3          OE  2020     1             1.0                    IMD
# 4          OE  2020     1             1.0                    IMD
# ...       ...   ...   ...             ...                    ...
# 15115      OE  2007    50             NaN  Lagos Business School
# 15116      OE  2007    50             NaN  Lagos Business School
# 15117      OE  2007    50             NaN  Lagos Business School
# 15118      OE  2007    50             NaN  Lagos Business School
# 15119      OE  2007    50             NaN  Lagos Business School
#
#       EBS 2019 TOP 20      Country Europe DACH              Ranking criteria  \
# 0                 Yes  Switzerland    Yes  Yes                 Aims achieved
# 1                 Yes  Switzerland    Yes  Yes                 Course design
# 2                 Yes  Switzerland    Yes  Yes                    Facilities
# 3                 Yes  Switzerland    Yes  Yes                       Faculty
# 4                 Yes  Switzerland    Yes  Yes             Faculty diversity
# ...               ...          ...    ...  ...                           ...
# 15115              No      Nigeria     No   No         New skills & learning
# 15116              No      Nigeria     No   No               Partner schools
# 15117              No      Nigeria     No   No                   Preparation
# 15118              No      Nigeria     No   No       Quality of participants
# 15119              No      Nigeria     No   No  Teaching methods & materials
#
#        Ranking weight  Value  HSG  20p  Relative_value     state  state_change
# 0                 8.4      4    0    0        0.053333 -0.466667            -1
# 1                 8.6      4    0    0        0.053333 -0.466667            -1
# 2                 7.6      3    0    0        0.040000 -0.600000            -1
# 3                 8.7      2    0    0        0.026667  0.066667             1
# 4                 5.0      5    0    1        0.066667  1.666667             1
# ...               ...    ...  ...  ...             ...       ...           ...
# 15115             8.8     50    0    0        1.000000  0.000000             0
# 15116             3.0     30    0    1        0.600000  0.000000             0
# 15117             7.8     50    0    0        1.000000  0.000000             0
# 15118             7.9     50    0    0        1.000000  0.000000             0
# 15119             8.3     50    0    0        1.000000  0.000000             0
#
# [15120 rows x 17 columns]

# %%
df_schnames.loc[df_schnames['School name'] == 'Lagos Business School']['address'][0]
# Out:
# 'Lekki - Epe Expy, Aja 106104, Lagos, Nigeria'

# %%
school_list = df_oe_v2["School name"].to_list()
full_addresses = []
latitudes = []
longitudes = []
for school_name in school_list:
    full_addresses.append(str(df_schnames.loc[df_schnames['School name'] == school_name]['address'][0]))
    latitudes.append(str(df_schnames.loc[df_schnames['School name'] == school_name]['glatitude'][0]))
    longitudes.append(str(df_schnames.loc[df_schnames['School name'] == school_name]['glongitude'][0]))
len(full_addresses)
# Out:
# 15120

# %%
df_oe_v2['full_address']=full_addresses
df_oe_v2['latitude']=latitudes
df_oe_v2['longitude']=longitudes
df_oe_v2
# Out:
#       Ranking  Year  Rank  3-year average            School name  \
# 0          OE  2020     1             1.0                    IMD
# 1          OE  2020     1             1.0                    IMD
# 2          OE  2020     1             1.0                    IMD
# 3          OE  2020     1             1.0                    IMD
# 4          OE  2020     1             1.0                    IMD
# ...       ...   ...   ...             ...                    ...
# 15115      OE  2007    50             NaN  Lagos Business School
# 15116      OE  2007    50             NaN  Lagos Business School
# 15117      OE  2007    50             NaN  Lagos Business School
# 15118      OE  2007    50             NaN  Lagos Business School
# 15119      OE  2007    50             NaN  Lagos Business School
#
#       EBS 2019 TOP 20      Country Europe DACH              Ranking criteria  \
# 0                 Yes  Switzerland    Yes  Yes                 Aims achieved
# 1                 Yes  Switzerland    Yes  Yes                 Course design
# 2                 Yes  Switzerland    Yes  Yes                    Facilities
# 3                 Yes  Switzerland    Yes  Yes                       Faculty
# 4                 Yes  Switzerland    Yes  Yes             Faculty diversity
# ...               ...          ...    ...  ...                           ...
# 15115              No      Nigeria     No   No         New skills & learning
# 15116              No      Nigeria     No   No               Partner schools
# 15117              No      Nigeria     No   No                   Preparation
# 15118              No      Nigeria     No   No       Quality of participants
# 15119              No      Nigeria     No   No  Teaching methods & materials
#
#        ...  Value  HSG  20p  Relative_value     state  state_change  \
# 0      ...      4    0    0        0.053333 -0.466667            -1
# 1      ...      4    0    0        0.053333 -0.466667            -1
# 2      ...      3    0    0        0.040000 -0.600000            -1
# 3      ...      2    0    0        0.026667  0.066667             1
# 4      ...      5    0    1        0.066667  1.666667             1
# ...    ...    ...  ...  ...             ...       ...           ...
# 15115  ...     50    0    0        1.000000  0.000000             0
# 15116  ...     30    0    1        0.600000  0.000000             0
# 15117  ...     50    0    0        1.000000  0.000000             0
# 15118  ...     50    0    0        1.000000  0.000000             0
# 15119  ...     50    0    0        1.000000  0.000000             0
#
#                                           full_addresses  \
# 0      Chem. de Bellerive 23, 1003 Lausanne, Switzerland
# 1      Chem. de Bellerive 23, 1003 Lausanne, Switzerland
# 2      Chem. de Bellerive 23, 1003 Lausanne, Switzerland
# 3      Chem. de Bellerive 23, 1003 Lausanne, Switzerland
# 4      Chem. de Bellerive 23, 1003 Lausanne, Switzerland
# ...                                                  ...
# 15115       Lekki - Epe Expy, Aja 106104, Lagos, Nigeria
# 15116       Lekki - Epe Expy, Aja 106104, Lagos, Nigeria
# 15117       Lekki - Epe Expy, Aja 106104, Lagos, Nigeria
# 15118       Lekki - Epe Expy, Aja 106104, Lagos, Nigeria
# 15119       Lekki - Epe Expy, Aja 106104, Lagos, Nigeria
#
#                                             full_address           latitude  \
# 0      Chem. de Bellerive 23, 1003 Lausanne, Switzerland         46.5104105
# 1      Chem. de Bellerive 23, 1003 Lausanne, Switzerland         46.5104105
# 2      Chem. de Bellerive 23, 1003 Lausanne, Switzerland         46.5104105
# 3      Chem. de Bellerive 23, 1003 Lausanne, Switzerland         46.5104105
# 4      Chem. de Bellerive 23, 1003 Lausanne, Switzerland         46.5104105
# ...                                                  ...                ...
# 15115       Lekki - Epe Expy, Aja 106104, Lagos, Nigeria  6.472829399999999
# 15116       Lekki - Epe Expy, Aja 106104, Lagos, Nigeria  6.472829399999999
# 15117       Lekki - Epe Expy, Aja 106104, Lagos, Nigeria  6.472829399999999
# 15118       Lekki - Epe Expy, Aja 106104, Lagos, Nigeria  6.472829399999999
# 15119       Lekki - Epe Expy, Aja 106104, Lagos, Nigeria  6.472829399999999
#
#                longitude
# 0              6.6219502
# 1              6.6219502
# 2              6.6219502
# 3              6.6219502
# 4              6.6219502
# ...                  ...
# 15115  3.603556299999999
# 15116  3.603556299999999
# 15117  3.603556299999999
# 15118  3.603556299999999
# 15119  3.603556299999999
#
# [15120 rows x 21 columns]

# %%
df_oe_v2.to_excel('df_oe_v3_geoinfo.xlsx')

# %%
df_schnames.to_excel('University_Geolocation.xlsx')

# %%
df_schnames
# Out:
#                                   School name  \
# 0                                         IMD
# 1                  University of Oxford: Saïd
# 2                                      Insead
# 3                University of Michigan: Ross
# 4        Stanford Graduate School of Business
# ..                                        ...
# 101              Wisconsin School of Business
# 102  University of Queensland Business School
# 103                    Duke University: Fuqua
# 104                Babson Executive Education
# 105   Macquarie Graduate School of Management
#
#                                                address  \
# 0    Chem. de Bellerive 23, 1003 Lausanne, Switzerland
# 1                      Park End St, Oxford OX1 1HP, UK
# 2         Bd de Constance, 77300 Fontainebleau, France
# 3             701 Tappan Ave, Ann Arbor, MI 48109, USA
# 4              655 Knight Way, Stanford, CA 94305, USA
# ..                                                 ...
# 101         975 University Ave, Madison, WI 53706, USA
# 102  Colin Clark, 39 Blair Dr, St Lucia QLD 4067, A...
# 103             100 Fuqua Drive, Durham, NC 27708, USA
# 104          231 Forest St, Babson Park, MA 02457, USA
# 105  99 Talavera Rd, Macquarie Park NSW 2113, Austr...
#
#                                 reformat_name  glatitude  glongitude
# 0                                         IMD  46.510410    6.621950
# 1                  University of Oxford: Saïd  51.753252   -1.268270
# 2                                      Insead  48.405113    2.685654
# 3                University of Michigan: Ross  42.272969  -83.737863
# 4        Stanford Graduate School of Business  37.428052 -122.161173
# ..                                        ...        ...         ...
# 101              Wisconsin School of Business  43.072709  -89.401636
# 102  University of Queensland Business School -27.494711  153.014247
# 103                    Duke University: Fuqua  35.998547  -78.945901
# 104                Babson Executive Education  42.296442  -71.265708
# 105   Macquarie Graduate School of Management -33.771314  151.116176
#
# [106 rows x 5 columns]

# %% [markdown]
# #### Using open street maps (not used in final)

# %%
# !pip install url
# !pip install requests

# %%
df_schnames['enc_add'].head(106)
# Out:
# 0                                           IMD
# 1                     University of Oxford Saïd
# 2                                        Insead
# 3                   University of Michigan Ross
# 4          Stanford Graduate School of Business
#                          ...
# 101                Wisconsin School of Business
# 102    University of Queensland Business School
# 103                       Duke University Fuqua
# 104                  Babson Executive Education
# 105     Macquarie Graduate School of Management
# Name: enc_add, Length: 106, dtype: object

# %%
import re
def clean_add(x):
    if "ï" in x:
        x.replace('ï','i')
    return re.sub(r'[^\w\s]', '', str(x))
df_schnames['enc_add'] = df_schnames['School name'].apply(clean_add)
df_schnames[df_schnames['School name']== "University of Oxford: Saïd"] ="Saïd Business School"
df_schnames[df_schnames['School name']== "University of Michigan: Ross"] ='Michigan Ross Business School'
df_schnames
# Out:
#                                   School name  \
# 0                                         IMD
# 1                        Saïd Business School
# 2                                      Insead
# 3               Michigan Ross Business School
# 4        Stanford Graduate School of Business
# ..                                        ...
# 101              Wisconsin School of Business
# 102  University of Queensland Business School
# 103                    Duke University: Fuqua
# 104                Babson Executive Education
# 105   Macquarie Graduate School of Management
#
#                                       enc_add
# 0                                         IMD
# 1                        Saïd Business School
# 2                                      Insead
# 3               Michigan Ross Business School
# 4        Stanford Graduate School of Business
# ..                                        ...
# 101              Wisconsin School of Business
# 102  University of Queensland Business School
# 103                     Duke University Fuqua
# 104                Babson Executive Education
# 105   Macquarie Graduate School of Management
#
# [106 rows x 2 columns]

# %%
import urllib
import requests


url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(df_schnames['enc_add'][1]) +'?format=json'
response = requests.get(url).json()
print('Latitude: '+response[0]['lat']+', Longitude: '+response[0]['lon'])
# Out:
# Latitude: 51.7537125, Longitude: -1.2684695174759821

# %%
# url = 'https://nominatim.openstreetmap.org/search/' 

# def geocode_lat(add):
#     url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(add) +'?format=json'
#     lat = requests.get(url).json()[0]['lat']
#     return lat
# def geocode_lon(add):
#     url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(add) +'?format=json'
#     lng = requests.get(url).json()[0]['lon']
#     return lng

# df_schnames['glatitude'] = df_schnames['School name'].apply(geocode_lat)
# df_schnames['glongitude'] = df_schnames['School name'].apply(geocode_lon)

# %%
fix = []
can = 0

for i in range(106):
    add = df_schnames['enc_add'][i]
    url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(df_schnames['enc_add'][i] ) +'?format=json'
    response = requests.get(url).json()
    try: 
        lat = response[0]['lat']        
#         print('Latitude: '+response[0]['lat']+', Longitude: '+response[0]['lon'])
        can +=1

    except: 
        fix.append(add)

# %%
fix
# Out:
# ['University of Chicago Booth',
#  'Washington University Olin',
#  'Stockholm School of Economics',
#  'University of Cambridge Judge',
#  'Western University Ivey',
#  'Hult Ashridge Executive Education',
#  'Kaist College of Business',
#  'Queens University Smith',
#  'Shanghai Jiao Tong University Antai',
#  'Gordon Institute of Business Science at UP',
#  'NHH Norwegian School of Economics',
#  'AGSM at UNSW Business School',
#  'National University of Singapore Business School',
#  'Thunderbird School of Global Management at ASU',
#  'University College Dublin Smurfit',
#  'Universidad de los Andes School of Management',
#  'York University Schulich',
#  'Eada Business School Barcelona',
#  'University of British Columbia Sauder',
#  'Frankfurt School of Finance and Management',
#  'University of Arizona Eller',
#  'Rotterdam School of Management Erasmus University',
#  'IAE Business School',
#  'Florida Atlantic University College of Business',
#  'Moscow School of Management Skolkovo',
#  'EMLyon Business School',
#  'BI Norwegian Business School',
#  'American University in Cairo School of Business',
#  'McGill University Desautels',
#  'Católica Lisbon School of Business and Economics',
#  'Solvay Brussels School of Economics and Management',
#  'Politecnico di Milano School of Management',
#  'Center for Creative Leadership',
#  'Boston University Questrom',
#  'Centrum PUCP Graduate Business School',
#  'MIT Sloan',
#  'Peking University Guanghua',
#  'USB Executive Development',
#  'ISCTE Business School',
#  'University of Pretoria Gibs',
#  'Fundação Instituto de Administração',
#  'Saint Paul Escola de Negócios',
#  'Northwestern University Kellogg',
#  'Sun Yatsen Business School',
#  'Xiamen University School of Management',
#  'University of Texas at Austin McCombs',
#  'University of California at Berkeley Haas',
#  'Euromed Management',
#  'University of Queensland Business School',
#  'Duke University Fuqua',
#  'Babson Executive Education',
#  'Macquarie Graduate School of Management']

# %%
can #with sch of biz
# Out:
# 0

# %%
len(fix) + can == 106
# Out:
# True

# %%
url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(df_schnames['School name'][0]) +'?format=json'
response = requests.get(url).json()
response[0]['']
# Out:
# {'place_id': 282412974,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 1762061,
#  'boundingbox': ['46.5089527', '46.5114253', '6.6185034', '6.6232768'],
#  'lat': '46.5099312',
#  'lon': '6.6214752240252075',
#  'display_name': 'IMD, 23, Chemin de Bellerive, Lausanne, District de Lausanne, Vaud, 1007, Schweiz/Suisse/Svizzera/Svizra',
#  'class': 'amenity',
#  'type': 'school',
#  'importance': 0.4798815985584707,
#  'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//education_school.p.20.png'}

# %% [markdown]
# <a id="2021"></a>
# <h3>Fixing 2021 data</h3><br>
# We found data of more performance markers for each university on the Financial Times Ranking website but they were only found for 2021. The rankings had also not yet been evaluated and announced on the site. Upon further exploratory work, it was also found that there are schools in the 2021 list that are not found in the previous year’s list of participating schools. Each school name was also spelled differently from the way it was spelled in the given dataset. In our correction of this data to prepare it for reasonable comparison with 2020 data, we first manually corrected the spelling of each school name that had a different spelling or wording. Next, we used the 2020 ranking to assign to the 2021 data by using inner join of the 2021 data set and a table of the school’s rankings in 2020. In essence, we also dropped the schools that appeared in 2021 but not in 2020. However, given that these data points were insufficient for a comparison analysis, we did not end up using this extended dataset.
#
# Additionally, using excel LOOKUP() functions and exchange rates found on the internet, currency values were standardized to that of CHF. This can be found in the 2021 Metadata FT OE.xlsx file.

# %%
#loading data
import pandas as pd
df_2021 = pd.read_excel("2021 Metadata FT OE.xlsx", index_col =0)

# %%
df_2021 = df_2021.rename(columns = {'School Name':'School name'})
df_2021
# Out:
#                                            School name Location (main campus)  \
# Year
# 2021                UCLA Anderson School of Management                     US
# 2021                          Western University: Ivey                 Canada
# 2021                             Incae Business School             Costa Rica
# 2021                    Eada Business School Barcelona                  Spain
# 2021        Politecnico di Milano School of Management                  Italy
# ...                                                ...                    ...
# 2021                    Nyenrode Business Universiteit            Netherlands
# 2021                              Iese Business School                  Spain
# 2021                          Mannheim Business School                Germany
# 2021  National University of Singapore Business School              Singapore
# 2021                            Henley Business School                     UK
#
#      Unnamed: 3 Tuition cost of GMP  Unnamed: 5 Tuition cost of AMP  \
# Year
# 2021        USD             $20,000         NaN              $7,500
# 2021        CAD             C$3,500         NaN             C$8,000
# 2021        CRC             $13,600         NaN              $9,000
# 2021        EUR              €4,500         NaN              €4,000
# 2021        EUR              €7,000         NaN              €5,000
# ...         ...                 ...         ...                 ...
# 2021        NaN             €14,995         NaN             €13,995
# 2021        NaN             €28,400         NaN             €28,400
# 2021        NaN              €7,500         NaN              €9,000
# 2021        NaN             S$5,990         NaN            S$30,000
# 2021        NaN              £6,750         NaN              £7,250
#
#       Unnamed: 7 Revenue  Repeat business (% of revenue)  No. of GMP progs  \
# Year
# 2021         NaN       D                            83.0                 3
# 2021         NaN       D                            38.0                 2
# 2021         NaN       C                            10.0                 4
# 2021         NaN       C                            35.0                 4
# 2021         NaN       C                            12.0                 9
# ...          ...     ...                             ...               ...
# 2021         NaN       B                            25.0                 8
# 2021         NaN       A                            40.0                36
# 2021         NaN       D                             5.0                 1
# 2021         NaN       C                            50.0                 5
# 2021         NaN       C                            33.0                56
#
#       ...  Progs in p'ship (orgs/co)  \
# Year  ...
# 2021  ...                          4
# 2021  ...                          7
# 2021  ...                          1
# 2021  ...                          8
# 2021  ...                          8
# ...   ...                        ...
# 2021  ...                         40
# 2021  ...                         13
# 2021  ...                          0
# 2021  ...                          5
# 2021  ...                          0
#
#                                    Largest flagship GMP  \
# Year
# 2021                                  Executive Program
# 2021                Ivey Performance Management Program
# 2021                          Programa de Alta Gerencia
# 2021                Sustainability & Innovation Program
# 2021        Executive Program in Digital Transformation
# ...                                                 ...
# 2021                     Leadership Development Program
# 2021             Programa de Desarrollo Directivo (PDD)
# 2021           General Management Analytics Certificate
# 2021  Leading with Big Data Analytics & Machine Lear...
# 2021     Professional Certificate in Executive Coaching
#
#      Avg teaching hours, GMP  Women on GMP (%)  GMP attendees, 2020  \
# Year
# 2021                     186              26.0                   57
# 2021                      25              72.0                   45
# 2021                     160              20.0                   81
# 2021                      60              39.0                  120
# 2021                     128               6.0                   34
# ...                      ...               ...                  ...
# 2021                     104              25.0                   40
# 2021                     203              31.0                1,354
# 2021                     300              38.0                   75
# 2021                      40              35.0                   65
# 2021                      49              59.0                2,354
#
#                           Largest flagship AMP  Unnamed: 23  \
# Year
# 2021              Corporate Governance Program          NaN
# 2021                   Ivey Leadership Program          NaN
# 2021                  Senior Executive Program          NaN
# 2021        International Leadership Programme          NaN
# 2021    Professional GBS Certification Program          NaN
# ...                                        ...          ...
# 2021    Nyenrode Commissarissencyclus 45-46-48          NaN
# 2021       Programa de Dirección General (PDG)          NaN
# 2021     Mannheim Agile Leadership Certificate          NaN
# 2021  Enterprise Leadership for Transformation          NaN
# 2021                  The Leadership Programme          NaN
#
#      Avg teaching hours, AMP  Women on AMP (%)  AMP attendees, 2020
# Year
# 2021                    33.0              70.0                   17
# 2021                    40.0              53.0                   58
# 2021                    50.0              30.0                   24
# 2021                    60.0              39.0                  193
# 2021                    36.0              26.0                   27
# ...                      ...               ...                  ...
# 2021                   144.0              33.0                  121
# 2021                   221.0              31.0                1,173
# 2021                    96.0              36.0                   52
# 2021                   168.0              26.0                   30
# 2021                    46.0              54.0                  330
#
# [91 rows x 26 columns]

# %%
df_for_rankings = pd.read_excel("OE_v1.xlsx",index_col =0)
df_2020 = df_for_rankings[df_for_rankings['Year']==2020]
df_2020
# Out:
#      Ranking  Year  Rank  3-year average            School name  \
# 0         OE  2020     1             1.0                    IMD
# 1         OE  2020     1             1.0                    IMD
# 2         OE  2020     1             1.0                    IMD
# 3         OE  2020     1             1.0                    IMD
# 4         OE  2020     1             1.0                    IMD
# ...      ...   ...   ...             ...                    ...
# 1195      OE  2020    75            73.0  Porto Business School
# 1196      OE  2020    75            73.0  Porto Business School
# 1197      OE  2020    75            73.0  Porto Business School
# 1198      OE  2020    75            73.0  Porto Business School
# 1199      OE  2020    75            73.0  Porto Business School
#
#      EBS 2019 TOP 20      Country Europe DACH              Ranking criteria  \
# 0                Yes  Switzerland    Yes  Yes                 Aims achieved
# 1                Yes  Switzerland    Yes  Yes                 Course design
# 2                Yes  Switzerland    Yes  Yes                    Facilities
# 3                Yes  Switzerland    Yes  Yes                       Faculty
# 4                Yes  Switzerland    Yes  Yes             Faculty diversity
# ...              ...          ...    ...  ...                           ...
# 1195              No     Portugal    Yes   No         New skills & learning
# 1196              No     Portugal    Yes   No               Partner schools
# 1197              No     Portugal    Yes   No                   Preparation
# 1198              No     Portugal    Yes   No       Quality of participants
# 1199              No     Portugal    Yes   No  Teaching methods & materials
#
#       Ranking weight  Value  HSG  20p
# 0                8.4      4    0    0
# 1                8.6      4    0    0
# 2                7.6      3    0    0
# 3                8.7      2    0    0
# 4                5.0      5    0    1
# ...              ...    ...  ...  ...
# 1195             8.7     75    0    0
# 1196             3.0     28    0    1
# 1197             7.7     74    0    0
# 1198             7.9     72    0    0
# 1199             8.3     74    0    0
#
# [1200 rows x 14 columns]

# %%
try1 = df_2020[['School name','Rank']].drop_duplicates()
try1.groupby('School name')['School name'].count()
# Out:
# School name
# AGSM at UNSW Business School                       1
# Aalto University                                   1
# Alberta School of Business                         1
# American University in Cairo School of Business    1
# Audencia Business School                           1
#                                                   ..
# Vlerick Business School                            1
# WHU – Otto Beisheim School of Management           1
# Washington University: Olin                        1
# Western University: Ivey                           1
# York University: Schulich                          1
# Name: School name, Length: 75, dtype: int64

# %%
try1[try1['School name']=='IMD']
# Out:
#   School name  Rank
# 0         IMD     1

# %%
try1
# Out:
#                                             School name  Rank
# 0                                                   IMD     1
# 16                           University of Oxford: Saïd     2
# 32                                               Insead     3
# 48                         University of Michigan: Ross     3
# 64                 Stanford Graduate School of Business     5
# ...                                                 ...   ...
# 1120                              Kedge Business School    71
# 1136   Católica Lisbon School of Business and Economics    72
# 1152  Solvay Brussels School of Economics and Manage...    73
# 1168         Politecnico di Milano School of Management    74
# 1184                              Porto Business School    75
#
# [75 rows x 2 columns]

# %%
try_inner = pd.merge(try1,df_2021, on='School name', how = 'inner')
try_inner
# Out:
#                                           School name  Rank  \
# 0                                                 IMD     1
# 1                          University of Oxford: Saïd     2
# 2                                              Insead     3
# 3                        University of Michigan: Ross     3
# 4                Stanford Graduate School of Business     5
# ..                                                ...   ...
# 61                              Lagos Business School    69
# 62                              Kedge Business School    71
# 63   Católica Lisbon School of Business and Economics    72
# 64  Solvay Brussels School of Economics and Manage...    73
# 65         Politecnico di Milano School of Management    74
#
#    Location (main campus) Unnamed: 3 Tuition cost of GMP  Unnamed: 5  \
# 0             Switzerland        NaN           SFr13,500         NaN
# 1                      UK        NaN              £8,900         NaN
# 2                  France        NaN             €15,600         NaN
# 3                      US        NaN              $7,300         NaN
# 4                      US        NaN             $19,000         NaN
# ..                    ...        ...                 ...         ...
# 61                Nigeria        NaN             $22,563         NaN
# 62                 France        NaN             €12,100         NaN
# 63               Portugal        NaN              €6,250         NaN
# 64                Belgium        NaN              €8,400         NaN
# 65                  Italy        EUR              €7,000         NaN
#
#    Tuition cost of AMP  Unnamed: 7 Revenue  Repeat business (% of revenue)  \
# 0            SFr30,000         NaN       A                            40.0
# 1              £18,500         NaN       A                            13.0
# 2              €29,000         NaN       A                            43.0
# 3               $7,750         NaN     NaN                            28.0
# 4              $78,000         NaN       A                            27.0
# ..                 ...         ...     ...                             ...
# 61             $44,165         NaN       C                            37.0
# 62              €6,200         NaN       C                            38.0
# 63              €9,500         NaN       C                            43.0
# 64             €10,950         NaN       D                             0.0
# 65              €5,000         NaN       C                            12.0
#
#     ...  Progs in p'ship (orgs/co)  \
# 0   ...                          2
# 1   ...                          9
# 2   ...                          8
# 3   ...                          2
# 4   ...                          1
# ..  ...                        ...
# 61  ...                          8
# 62  ...                         67
# 63  ...                          7
# 64  ...                          3
# 65  ...                          8
#
#                             Largest flagship GMP  Avg teaching hours, GMP  \
# 0                    High Performance Leadership                       48
# 1   Oxford High Performance Leadership Programme                       58
# 2        Management Acceleration Programme (MAP)                      120
# 3                      Strategic Leaders Program                       34
# 4          Stanford LEAD Online Business Program                      333
# ..                                           ...                      ...
# 61                   Senior Management Programme                      206
# 62               Programme de Management Général                      455
# 63                    General Management Program                      143
# 64              Accelerated Management Programme                      144
# 65   Executive Program in Digital Transformation                      128
#
#    Women on GMP (%)  GMP attendees, 2020  \
# 0              26.0                  212
# 1              35.0                  219
# 2              29.0                   75
# 3              30.0                   70
# 4              33.0                1,709
# ..              ...                  ...
# 61             40.0                1,487
# 62             58.0                   52
# 63             57.0                   81
# 64             37.0                  214
# 65              6.0                   34
#
#                                  Largest flagship AMP  Unnamed: 23  \
# 0                         Advanced Management Program          NaN
# 1   Oxford Advanced Management and Leadership Prog...          NaN
# 2                 Advanced Management Programme (AMP)          NaN
# 3                                 The Positive Leader          NaN
# 4             SEP (2019) (Stanford Executive Program)          NaN
# ..                                                ...          ...
# 61                      Advanced Management Programme          NaN
# 62   Strategical development for Health Organizations          NaN
# 63           Executive Program in Advanced Management          NaN
# 64                     Executive Master in Management          NaN
# 65             Professional GBS Certification Program          NaN
#
#     Avg teaching hours, AMP Women on AMP (%)  AMP attendees, 2020
# 0                     150.0             16.0                   19
# 1                     202.0             23.0                   73
# 2                     160.0             19.0                   58
# 3                      29.5             44.0                   25
# 4                     240.0             20.0                  255
# ..                      ...              ...                  ...
# 61                    163.0             27.0                  124
# 62                     36.0             64.0                   73
# 63                    167.0             38.0                   18
# 64                    220.0             24.0                   60
# 65                     36.0             26.0                   27
#
# [66 rows x 27 columns]

# %%
inner_worked = try_inner.to_excel('modified_2021_v1.xlsx')
