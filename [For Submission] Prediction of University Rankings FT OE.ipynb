# %% [markdown]
# # Prediction using Correlation Analysis and Multiple Linear Regression

# %% [markdown]
# ### Loading libraries and original dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Read data
ranking_data = pd.read_excel("FT OE rankings 2007-2020.xlsx")

# %%
#create constant dataset 
ranking_data_const = pd.read_excel("FT OE rankings 2007-2020.xlsx")
ranking_data_const
# Out:
#       Ranking       Year  Rank  3-year average            School name  \
# 0          OE 2020-01-01     1             1.0                    IMD
# 1          OE 2020-01-01     1             1.0                    IMD
# 2          OE 2020-01-01     1             1.0                    IMD
# 3          OE 2020-01-01     1             1.0                    IMD
# 4          OE 2020-01-01     1             1.0                    IMD
# ...       ...        ...   ...             ...                    ...
# 15115      OE 2007-01-01    50             NaN  Lagos Business School
# 15116      OE 2007-01-01    50             NaN  Lagos Business School
# 15117      OE 2007-01-01    50             NaN  Lagos Business School
# 15118      OE 2007-01-01    50             NaN  Lagos Business School
# 15119      OE 2007-01-01    50             NaN  Lagos Business School
#
#       EBS 2019 TOP 20      Country Europe DACH              Ranking criteria  \
# 0                 Yes  Switzerland    Yes  Yes                 Aims achieved
# 1                 Yes  Switzerland    Yes  Yes                 Course design
# 2                 Yes  Switzerland    Yes  Yes                    Facilities
# 3                 Yes  Switzerland    Yes  Yes                       Faculty
# 4                 Yes  Switzerland    Yes  Yes             Faculty diversity
# ...               ...          ...    ...  ...                           ...
# 15115              No      Nigeria     No   No         New skills & learning
# 15116              No      Nigeria     No   No               Partner schools
# 15117              No      Nigeria     No   No                   Preparation
# 15118              No      Nigeria     No   No       Quality of participants
# 15119              No      Nigeria     No   No  Teaching methods & materials
#
#        Ranking weight  Value
# 0                 8.4      4
# 1                 8.6      4
# 2                 7.6      3
# 3                 8.7      2
# 4                 5.0      5
# ...               ...    ...
# 15115             8.8     50
# 15116             3.0     30
# 15117             7.8     50
# 15118             7.9     50
# 15119             8.3     50
#
# [15120 rows x 12 columns]

# %% [markdown]
# <h4>Removing data columns of the attributes not required for the consideration of factors that affect the ranking in our multiple linear regression model</h4>

# %%
df_only_factors = ranking_data.drop(["Ranking", "3-year average", "Ranking weight"],axis = 1)
df_only_factors["Year"]= df_only_factors["Year"].dt.yea
df_only_factors

# %% [markdown]
# <h4>Converting data to binary 0 and 1 for consideration in the MLR Model</h4>

# %%
df_only_factors_binary = df_only_factors.replace(['Yes', 'No'], [1,0])
df_only_factors_binary
# Out:
#        Year  Rank            School name  EBS 2019 TOP 20      Country  \
# 0      2020     1                    IMD                1  Switzerland
# 1      2020     1                    IMD                1  Switzerland
# 2      2020     1                    IMD                1  Switzerland
# 3      2020     1                    IMD                1  Switzerland
# 4      2020     1                    IMD                1  Switzerland
# ...     ...   ...                    ...              ...          ...
# 15115  2007    50  Lagos Business School                0      Nigeria
# 15116  2007    50  Lagos Business School                0      Nigeria
# 15117  2007    50  Lagos Business School                0      Nigeria
# 15118  2007    50  Lagos Business School                0      Nigeria
# 15119  2007    50  Lagos Business School                0      Nigeria
#
#        Europe  DACH              Ranking criteria  Value
# 0           1     1                 Aims achieved      4
# 1           1     1                 Course design      4
# 2           1     1                    Facilities      3
# 3           1     1                       Faculty      2
# 4           1     1             Faculty diversity      5
# ...       ...   ...                           ...    ...
# 15115       0     0         New skills & learning     50
# 15116       0     0               Partner schools     30
# 15117       0     0                   Preparation     50
# 15118       0     0       Quality of participants     50
# 15119       0     0  Teaching methods & materials     50
#
# [15120 rows x 9 columns]

# %% [markdown]
# <h4> Exporting to excel for manual transposing</h4>

# %%
df_only_factors_binary.to_excel("for_corr.xlsx")

# %% [markdown]
# <h3> Loading transposed data </h3>

# %% [markdown]
# This data includes all the rows from the original dataset and the following code takes each row with the first ranking criteria "Aims Achieved" as the main datarow for that year. The rest are duplicates due to the way the table was partially transposed in excel manually.

# %%
transposed = pd.read_excel("for_corr.xlsx",index_col=0)
transposed
# Out:
#        Year  Rank            School name  EBS 2019 TOP 20      Country  \
# 0      2020     1                    IMD                1  Switzerland
# 1      2020     1                    IMD                1  Switzerland
# 2      2020     1                    IMD                1  Switzerland
# 3      2020     1                    IMD                1  Switzerland
# 4      2020     1                    IMD                1  Switzerland
# ...     ...   ...                    ...              ...          ...
# 15115  2007    50  Lagos Business School                0      Nigeria
# 15116  2007    50  Lagos Business School                0      Nigeria
# 15117  2007    50  Lagos Business School                0      Nigeria
# 15118  2007    50  Lagos Business School                0      Nigeria
# 15119  2007    50  Lagos Business School                0      Nigeria
#
#        Europe  DACH              Ranking criteria  Value  Aims achieved  ...  \
# 0           1     1                 Aims achieved      4              4  ...
# 1           1     1                 Course design      4              4  ...
# 2           1     1                    Facilities      3              3  ...
# 3           1     1                       Faculty      2              2  ...
# 4           1     1             Faculty diversity      5              5  ...
# ...       ...   ...                           ...    ...            ...  ...
# 15115       0     0         New skills & learning     50             50  ...
# 15116       0     0               Partner schools     30             30  ...
# 15117       0     0                   Preparation     50             50  ...
# 15118       0     0       Quality of participants     50             50  ...
# 15119       0     0  Teaching methods & materials     50             50  ...
#
#        Follow-up  Food & accommodation  Growth  International location  \
# 0              8                     2      29                      37
# 1              2                    29      37                       6
# 2             29                    37       6                       3
# 3             37                     6       3                      43
# 4              6                     3      43                       7
# ...          ...                   ...     ...                     ...
# 15115          0                     0       0                       0
# 15116          0                     0       0                       0
# 15117          0                     0       0                       0
# 15118          0                     0       0                       0
# 15119          0                     0       0                       0
#
#        International participants  New skills & learning  Partner schools  \
# 0                               6                      3               43
# 1                               3                     43                7
# 2                              43                      7                4
# 3                               7                      4                1
# 4                               4                      1                3
# ...                           ...                    ...              ...
# 15115                           0                      0                0
# 15116                           0                      0                0
# 15117                           0                      0                0
# 15118                           0                      0                0
# 15119                           0                      0                0
#
#        Preparation  Quality of participants  Teaching methods & materials
# 0                7                        4                             1
# 1                4                        1                             3
# 2                1                        3                             3
# 3                3                        3                             9
# 4                3                        9                             3
# ...            ...                      ...                           ...
# 15115            0                        0                             0
# 15116            0                        0                             0
# 15117            0                        0                             0
# 15118            0                        0                             0
# 15119            0                        0                             0
#
# [15120 rows x 25 columns]

# %%
final_corr_data = transposed[transposed["Ranking criteria"]== "Aims achieved"]
final_corr_data = final_corr_data.drop(['Ranking criteria', 'Value' ], axis =1)

# %%
final_corr_data
# Out:
#        Year  Rank                                        School name  \
# 0      2020     1                                                IMD
# 16     2020     2                         University of Oxford: Saïd
# 32     2020     3                                             Insead
# 48     2020     3                       University of Michigan: Ross
# 64     2020     5               Stanford Graduate School of Business
# ...     ...   ...                                                ...
# 15040  2007    46   Católica Lisbon School of Business and Economics
# 15056  2007    46                          USB Executive Development
# 15072  2007    48                               Wits Business School
# 15088  2007    49  Solvay Brussels School of Economics and Manage...
# 15104  2007    50                              Lagos Business School
#
#        EBS 2019 TOP 20       Country  Europe  DACH  Aims achieved  \
# 0                    1   Switzerland       1     1              4
# 16                   1            UK       1     0              3
# 32                   1        France       1     0              6
# 48                   0            US       0     0              2
# 64                   0            US       0     0              1
# ...                ...           ...     ...   ...            ...
# 15040                0      Portugal       1     0             48
# 15056                0  South Africa       0     0             46
# 15072                0  South Africa       0     0             49
# 15088                0       Belgium       1     0             47
# 15104                0       Nigeria       0     0             50
#
#        Course design  Facilities  ...  Follow-up  Food & accommodation  \
# 0                  4           3  ...          8                     2
# 16                 3           9  ...          3                    17
# 32                 8           5  ...         10                     8
# 48                 1           1  ...         20                    11
# 64                13           6  ...         15                     1
# ...              ...         ...  ...        ...                   ...
# 15040             46          36  ...         40                    42
# 15056             47          44  ...         48                    45
# 15072             49          48  ...         50                    47
# 15088             48          45  ...         47                    50
# 15104             50          49  ...         44                    43
#
#        Growth  International location  International participants  \
# 0          29                      37                           6
# 16         35                      36                           9
# 32         31                      21                           4
# 48         38                      20                          32
# 64         42                      56                          10
# ...       ...                     ...                         ...
# 15040      49                      35                          34
# 15056      13                      23                          33
# 15072      10                      30                          40
# 15088      48                      36                          10
# 15104       3                      43                          43
#
#        New skills & learning  Partner schools  Preparation  \
# 0                          3               43            7
# 16                         5               16            5
# 32                        17               26           10
# 48                         2               30            4
# 64                         4               36            3
# ...                      ...              ...          ...
# 15040                     46               30           45
# 15056                     44               40           47
# 15072                     48               30           48
# 15088                     49               21           49
# 15104                     50               30           50
#
#        Quality of participants  Teaching methods & materials
# 0                            4                             1
# 16                           2                             4
# 32                           3                             5
# 48                           8                             2
# 64                           1                             6
# ...                        ...                           ...
# 15040                       46                            47
# 15056                       47                            46
# 15072                       42                            48
# 15088                       40                            49
# 15104                       50                            50
#
# [945 rows x 23 columns]

# %%
final_corr_data.to_excel("correlation analysis.xlsx")

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(final_corr_data.corr(), cmap='coolwarm', annot=True)
plt.savefig('correlation_heatmap_ranking_criteria.png')

# %%
corr_values = final_corr_data.corr()
corr_values.to_excel('Correlation_DV.xlsx')

# %% [markdown]
# ### Multiple Linear Regression Model

# %%
final_corr_data.columns
# Out:
# Index(['Year', 'Rank', 'School name', 'EBS 2019 TOP 20', 'Country', 'Europe',
#        'DACH', 'Aims achieved', 'Course design', 'Facilities', 'Faculty',
#        'Faculty diversity', 'Female participants', 'Follow-up',
#        'Food & accommodation', 'Growth', 'International location',
#        'International participants', 'New skills & learning',
#        'Partner schools', 'Preparation', 'Quality of participants',
#        'Teaching methods & materials'],
#       dtype='object')

# %%
x = final_corr_data[['EBS 2019 TOP 20', 'Europe',
       'DACH', 'Aims achieved', 'Course design', 'Facilities', 'Faculty',
       'Faculty diversity', 'Female participants', 'Follow-up',
       'Food & accommodation', 'Growth', 'International location',
       'International participants', 'New skills & learning',
       'Partner schools', 'Preparation', 'Quality of participants',
       'Teaching methods & materials']]
y = final_corr_data['Rank']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 100)

# %%
from sklearn.linear_model import LinearRegression
mlr = LinearRegression()  
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print("Intercept: ", mlr.intercept_)
print("Coefficients:")
list(zip(x, mlr.coef_))
# Out:
# Intercept:  -4.855405496316678
# Coefficients:
# [('EBS 2019 TOP 20', -0.21319795878295206),
#  ('Europe', -0.596850866320376),
#  ('DACH', 0.6113631668236942),
#  ('Aims achieved', 0.06168392685684804),
#  ('Course design', 0.12317796111512827),
#  ('Facilities', 0.10754860797885535),
#  ('Faculty', 0.14892119864067307),
#  ('Faculty diversity', 0.053086123571378104),
#  ('Female participants', -0.0645247072279486),
#  ('Follow-up', 0.0872384969218609),
#  ('Food & accommodation', 0.07167636557445314),
#  ('Growth', 0.03758059926097043),
#  ('International location', 0.015325013754711044),
#  ('International participants', 0.04079045474578961),
#  ('New skills & learning', 0.14466971882512644),
#  ('Partner schools', 0.02992355598991149),
#  ('Preparation', 0.1234929755698816),
#  ('Quality of participants', 0.08621138805316585),
#  ('Teaching methods & materials', 0.07979802790586886)]

# %%
model_coeff = pd.DataFrame(mlr.coef_,['EBS 2019 TOP 20', 'Europe',
       'DACH', 'Aims achieved', 'Course design', 'Facilities', 'Faculty',
       'Faculty diversity', 'Female participants', 'Follow-up',
       'Food & accommodation', 'Growth', 'International location',
       'International participants', 'New skills & learning',
       'Partner schools', 'Preparation', 'Quality of participants',
       'Teaching methods & materials'], columns=['Coefficients'])
model_coeff
# Out:
#                               Coefficients
# EBS 2019 TOP 20                  -0.213198
# Europe                           -0.596851
# DACH                              0.611363
# Aims achieved                     0.061684
# Course design                     0.123178
# Facilities                        0.107549
# Faculty                           0.148921
# Faculty diversity                 0.053086
# Female participants              -0.064525
# Follow-up                         0.087238
# Food & accommodation              0.071676
# Growth                            0.037581
# International location            0.015325
# International participants        0.040790
# New skills & learning             0.144670
# Partner schools                   0.029924
# Preparation                       0.123493
# Quality of participants           0.086211
# Teaching methods & materials      0.079798

# %%
model_coeff.to_excel('model_coefficients.xlsx')

# %% [markdown]
# #### Predicted values

# %%
#Prediction of test set
y_pred_mlr= mlr.predict(x_test)
#Predicted values
print("Prediction for test set: {}".format(y_pred_mlr))
# Out:
# Prediction for test set: [63.13583193 74.40838257 45.25516571 57.78092604 63.57396492  2.37438307
#  10.26008788 12.90696611 19.22462641 52.31297736 12.43820365 49.38235362
#  24.70593564 50.93323464 48.92745386 73.86858337 40.65526663 29.25949665
#  51.58610803 32.48189155 46.22405755 49.51453017 29.61459467 22.82709036
#   9.95465819 21.54058147 38.48071357 15.07134825 65.96586814 21.43580193
#  65.89810794 19.15963898 23.877085   35.33004289  7.83242185 75.44258025
#  51.73522606 27.84657346 23.61365661  3.4479478  38.81428538 17.3504316
#  49.54297332 39.38732969 43.30543286 38.8440453  65.19497848 13.21372445
#  30.5767218  68.22264661 57.40070765 13.58240894 66.98530768  3.71754103
#  29.35557069 76.81373229  2.30935183 21.84440772 13.77543474 39.78421484
#  45.20429016 63.76875737 69.42003873 19.64642541 46.89871336 42.95410951
#  70.98087904 43.72782776 10.49288609 49.54108639 39.59990221  9.15394907
#  40.44665044 18.84421021 51.27419512 57.90715341 62.59542622  4.03514347
#  46.87293746 44.675142    0.85444999 18.39370301 20.97718404 44.16517892
#  19.47516238 44.41441567 46.66436453 32.46496714 66.47747896 47.44179349
#  30.44811327 36.67538269 22.04771726 23.68241328  5.38751654 47.07062196
#  25.04573324 15.85521884 40.59613785 52.66788961 22.03734773 10.11765171
#  62.56949296 45.36528238 36.17967851 49.00423304 64.35313195 31.41688081
#  11.1703255  51.37979433 71.21022001  4.19830143 45.74967767 33.34574063
#   2.33265374 19.18925612 45.45364899 11.03503244 58.44691781 20.38976172
#  21.98799516 15.50371672  0.90888662 70.19546017 42.09558847 34.36652499
#  24.41770609  4.84361478 40.78819192  8.07449946 33.53550879 75.28437564
#  31.54964675 14.12067215 47.49399599 54.50930353 54.49321441 13.16419621
#  69.65630627 34.73099608 61.03016735 12.13688053 37.30372356 43.91989734
#  50.92232349 72.78127243 28.86486952 47.68160402 24.13992663  8.80766661
#  70.52956861 40.35398677 72.07021388 57.56814997 18.98636442 13.09440818
#  41.56421997  4.22253145 26.38573638 10.53701931 72.61798018  3.2448886
#   3.64393389 46.22473884 61.79802912  7.8544562   5.22833115  7.41206447
#  32.28211329 27.54774285 40.08345784 59.87075257  6.37706531 22.3175581
#   2.88760135 44.15179317 28.14118813  8.30990678 62.23732702 63.36194381
#  14.85960486 26.00996021 14.88627788 40.71974915 40.08767451 12.48109013
#  38.92007416 45.08439331 18.68640122 50.40755488 18.89667894 70.53645529
#  11.04723586 53.01812745 23.23503217 41.77662863 34.97537327 43.10987835
#  55.43421657 53.08598531 37.22154777 23.42939123 35.6754826  12.48708453
#  30.82514292 19.60201308 28.92357001 69.76157899 45.65152586 56.29651678
#  42.77808242 21.20383134 41.35379788 12.62099205 77.55469952 49.55965113
#  50.87570219 21.73347001 46.69895036 16.91747294 34.21418021 15.9651523
#   4.91157328  5.69721265 62.77896959 36.36012661 52.44285632 17.91604655
#  47.98746786 43.38674586 70.45551182 -0.31629034 72.68144789 51.16848743
#  42.02603851 29.2636986  46.78931942 35.66012843 55.23508018 41.90709736
#  61.12678138 16.2246057  34.3334928  25.48835872 13.99440869 36.4282782
#  66.50143119 27.30512585 26.25624048 58.73470011 81.93383668 10.43488414
#  63.69297906 49.65491742 12.55467761 42.55317087 62.52371336 49.39060206
#  47.23140322 10.89864492  6.93773961 11.44772928  6.62859088 33.9834498
#  25.25924943 50.00591301 22.39772193 12.73509951 12.98490364 41.25710272
#  71.30845511 21.7316745  16.84762247 39.00481587 64.94633171 47.1529471
#  51.32090895 35.11264274 46.89982857 65.39798411 47.9797143  36.43454753
#  39.07171324 23.12355751]

# %%
#visualizing actual and predicted values
mlr_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred_mlr})
mlr_diff.head()
# Out:
#       Actual value  Predicted value
# 2288            69        63.135832
# 3664            75        74.408383
# 1856            40        45.255166
# 2144            57        57.780926
# 5952            63        63.573965

# %% [markdown]
# ### Model Evaluation

# %%
#Model Evaluation
from sklearn import metrics
meanAbErr = metrics.mean_absolute_error(y_test, y_pred_mlr)
meanSqErr = metrics.mean_squared_error(y_test, y_pred_mlr)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_mlr))
print('R squared: {:.2f}'.format(mlr.score(x,y)*100), "of the data fits the regression model")
print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)
# Out:
# R squared: 98.81 of the data fits the regression model
# Mean Absolute Error: 1.9639101526323073
# Mean Square Error: 5.936920012693164
# Root Mean Square Error: 2.436579572411532

# %% [markdown]
# <h4>Check the residual plots for assumptions of Linear Regression</h4>

# %%
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_mlr})
results['residuals'] = results['Actual'] - results['Predicted']
results['residuals'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.scatter(results['Predicted'], results['residuals'],  color='blue')

# %% [markdown]
# <h4>Get the p values of the variables to check for significance</h4>

# %%
#In order to get the p values of the linear regression model we use statsmodels.api library 
import statsmodels.api as sm

mod = sm.OLS(y_train,x_train)

m1 = mod.fit()

p_values = m1.summary2().tables[1]['P>|t|']

# %%
round(p_values,4)
# Out:
# EBS 2019 TOP 20                 0.0000
# Europe                          0.0928
# DACH                            0.3423
# Aims achieved                   0.0040
# Course design                   0.0000
# Facilities                      0.0000
# Faculty                         0.0000
# Faculty diversity               0.0000
# Female participants             0.0000
# Follow-up                       0.0000
# Food & accommodation            0.0000
# Growth                          0.0000
# International location          0.5309
# International participants      0.0000
# New skills & learning           0.0000
# Partner schools                 0.0005
# Preparation                     0.0000
# Quality of participants         0.0000
# Teaching methods & materials    0.0029
# Name: P>|t|, dtype: float64
